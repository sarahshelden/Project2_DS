# %%
# import dependencies
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize

from datetime import date

today = str(date.today())

listx = ["33.972386,-84.231986","47.6062,-122.3321", "42.3601,-71.0589","34.0522,-118.2437"]
# listname = ["Norcross", "Seattle", "Boston", "Los Angeles"]


dflist = pd.DataFrame()

for i in listx:
    url = f"https://api.darksky.net/forecast/fb0e09b8e9092cef1008bfe2eef00118/{i}"
    #print(url)
    response = requests.get(url)
    data = response.json()
    citydf = json_normalize(data['hourly']['data'])
    df = citydf.loc[:,["time","temperature","pressure","humidity"]]
    df['clean time'] = pd.to_datetime(df['time'], unit='s')
    df = df[["clean time", "temperature", "pressure","humidity"]]
    df['city'] = i
    df['run_date'] = today
    dflist = dflist.append(df)
    
dflist.head()
# Out:
#            clean time  temperature  pressure  humidity                  city  \
# 0 2019-04-17 03:00:00        58.60   1021.50      0.68  33.972386,-84.231986
# 1 2019-04-17 04:00:00        56.66   1021.41      0.73  33.972386,-84.231986
# 2 2019-04-17 05:00:00        55.31   1021.18      0.76  33.972386,-84.231986
# 3 2019-04-17 06:00:00        55.45   1020.75      0.72  33.972386,-84.231986
# 4 2019-04-17 07:00:00        54.94   1020.43      0.72  33.972386,-84.231986
#
#      run_date
# 0  2019-04-16
# 1  2019-04-16
# 2  2019-04-16
# 3  2019-04-16
# 4  2019-04-16

# %%
with open('Agg_Data.csv', 'a') as f:
    dflist.to_csv(f, header=False)
